# %%
import numpy as np
import time 


#Creating a random 10x10 Matrix
A = np.random.rand(10, 10)

#Creating 10 element random vector
b = np.random.rand(10)

#Creating the timer to measure the time taken to solve the linear equation
start = time.time()

#Solving the linear equation Ax = b for x
x = np.linalg.solve(A, b)

#ending the timer
end = time.time()

print("Solution: \n", x)
print("Elapsed time:", end - start, "seconds")
# Out:
# Solution:
#  [-0.64511403 -0.27870798  0.75313621 -1.7056961   1.17048575  1.8982457
#   1.27014931  0.67816935 -1.03432428 -0.59870153]
# Elapsed time: 0.000675201416015625 seconds

# %%
import numpy as np
